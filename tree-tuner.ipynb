# %%
import pandas as pd, numpy as np
import duckdb

import sys
# !{sys.executable} -m pip install --user streamlit

import streamlit as st
from sklearn.datasets import fetch_openml
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve, confusion_matrix
import plotly.graph_objects as go
# Out:
# Requirement already satisfied: streamlit in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (1.48.1)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from streamlit) (6.1.0)
# Requirement already satisfied: click<9,>=7.0 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/site-packages (from streamlit) (2.3.2)
# Requirement already satisfied: packaging<26,>=20 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/site-packages (from streamlit) (2.3.1)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/site-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from streamlit) (6.32.0)
# Requirement already satisfied: pyarrow>=7.0 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from streamlit) (4.14.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.1.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from requests<3,>=2.27->streamlit) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from requests<3,>=2.27->streamlit) (2025.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.27.0)
# Requirement already satisfied: six>=1.5 in /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: /usr/local/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip

# %%
@st.cache_data
def load_data():
    adult = fetch_openml("adult", version=2, as_frame=True)
    df = adult.frame.rename(columns={"class":"target"})
    fe = duckdb.sql("""
        WITH base AS (
            SELECT *,
                CASE WHEN education IN ('Bachelors','Masters','Doctorate') THEN 1 ELSE 0 END AS is_degree,
                CASE WHEN "hours-per-week" >= 50 THEN 1 ELSE 0 END AS long_hours,
                CASE WHEN "marital-status" LIKE 'Married-%' THEN 1 ELSE 0 END AS married_any,
                CASE 
                  WHEN "capital-gain"=0 THEN '0'
                  WHEN "capital-gain"<2000 THEN '0-2k'
                  WHEN "capital-gain"<5000 THEN '2-5k'
                  WHEN "capital-gain"<10000 THEN '5-10k'
                  ELSE '10k+'
                END AS cap_gain_bucket
            FROM df
        )
        SELECT * FROM base
    """).df()
    return fe

df = load_data()
X = df.drop(columns=["target"])
y = (df["target"]==">50K").astype(int)

num_cols = X.select_dtypes(include=np.number).columns.tolist()
cat_cols = [c for c in X.columns if c not in num_cols]

preprocess = ColumnTransformer([
    ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols),
], remainder="passthrough")

st.title("Pruning Playground — Decision Tree on Adult Income")
st.write("Tune **pre-pruning** and **post-pruning** to see how complexity vs performance trades off.")

max_depth = st.slider("max_depth (None=0)", 0, 30, 8)
min_leaf = st.slider("min_samples_leaf", 1, 100, 10)
min_split = st.slider("min_samples_split", 2, 200, 20)
ccp_alpha = st.slider("ccp_alpha (post-pruning)", 0.0, 0.02, 0.0, 0.0005)

clf = DecisionTreeClassifier(
    random_state=42,
    max_depth=None if max_depth==0 else max_depth,
    min_samples_leaf=min_leaf,
    min_samples_split=min_split,
    ccp_alpha=ccp_alpha
)
pipe = Pipeline([("prep", preprocess), ("clf", clf)])
pipe.fit(X, y)

proba = pipe.predict_proba(X)[:,1]
auc = roc_auc_score(y, proba)
st.metric("AUC", f"{auc:.3f}")

fpr, tpr, _ = roc_curve(y, proba)
fig = go.Figure()
fig.add_trace(go.Scatter(x=fpr, y=tpr, mode="lines", name="ROC"))
fig.add_trace(go.Scatter(x=[0,1], y=[0,1], mode="lines", name="Chance", line=dict(dash="dash")))
fig.update_layout(title="ROC Curve", xaxis_title="FPR", yaxis_title="TPR")
st.plotly_chart(fig, use_container_width=True)

thr = st.slider("Classification threshold", 0.05, 0.95, 0.5, 0.01)
pred = (proba >= thr).astype(int)
cm = confusion_matrix(y, pred)

fig2 = go.Figure(data=go.Heatmap(z=cm, x=["Pred 0","Pred 1"], y=["True 0","True 1"], text=cm, texttemplate="%{text}"))
fig2.update_layout(title=f"Confusion Matrix @ threshold={thr:.2f}")
st.plotly_chart(fig2, use_container_width=True)
# Out:
# 2025-08-19 13:58:29.235 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-08-19 13:58:29.300 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-08-19 13:58:29.305 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:29.772
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/sumedhauppal/Library/Python/3.11/lib/python/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-08-19 13:58:29.773 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:29.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:29.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.281 Thread 'Thread-4': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.282 Thread 'Thread-4': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.283 Thread 'Thread-4': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.418 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.419 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.437 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.438 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.439 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.444 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.452 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.465 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.481 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.483 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.574 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.583 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.587 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:30.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:31.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:31.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:31.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:31.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:31.855 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:31.859 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:31.861 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:31.862 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:31.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:31.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:31.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:31.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:31.894 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:31.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:31.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:31.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:31.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:31.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-19 13:58:31.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
